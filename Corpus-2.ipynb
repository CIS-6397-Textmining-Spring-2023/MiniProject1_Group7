# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %% [markdown]
# ### corpus-2

# %% [markdown]
# ### top 30 words from corpus 2

# %%
import os
import glob
from collections import Counter
import matplotlib.pyplot as plt

# Define the path to your corpus folder
corpus_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\Corpus2\\Corpus2'

# Function to read and tokenize a text file
def read_and_tokenize(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
        words = text.split()
        return words

# Initialize a Counter to store word frequencies
word_counter = Counter()

# Iterate through all text files in the corpus folder
for file_path in glob.glob(os.path.join(corpus_folder, '*.txt')):
    words = read_and_tokenize(file_path)
    word_counter.update(words)

# Sort the word frequencies in descending order
word_freq = word_counter.most_common()

top_words = 30  # Number of top words to print
for i, (word, freq) in enumerate(word_freq):
    if i >= top_words:
        break
    print(f'{word}: {freq}')
# If you want to visualize the distribution, you can use a bar chart
top_words = 30  # Number of top words to visualize
top_words_data = word_freq[:top_words]

words, frequencies = zip(*top_words_data)

plt.figure(figsize=(12, 6))
plt.bar(words, frequencies)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title(f'Top {top_words} Words in the Corpus-2')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Create a dictionary from the words and frequencies
word_freq_dict = {word: freq for word, freq in zip(words, frequencies)}

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq_dict)

# Display the word cloud using Matplotlib
plt.figure(figsize=(7, 3))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# the: 115803
# and: 77418
# to: 64200
# of: 63391
# a: 45610
# I: 36190
# in: 34510
# was: 28604
# he: 27138
# that: 27092
# his: 23385
# with: 21080
# had: 19018
# her: 18334
# not: 17286
# for: 17103
# it: 16924
# you: 16841
# as: 16024
# she: 14742
# at: 14715
# on: 13383
# is: 13272
# be: 12614
# my: 11262
# have: 10838
# but: 10388
# all: 10067
# him: 8939
# said: 8875

# %% [markdown]
# #### Different k - most frequent words

# %%
# Define the path to your corpus folder
corpus_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\Corpus2\\Corpus2'

# Function to read and tokenize a text file
def read_and_tokenize(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
        words = text.split()
        return words

# Initialize a Counter to store word frequencies
word_counter = Counter()

# Iterate through all text files in the corpus folder
for file_path in glob.glob(os.path.join(corpus_folder, '*.txt')):
    words = read_and_tokenize(file_path)
    word_counter.update(words)

# Sort the word frequencies in descending order
word_freq = word_counter.most_common()

# Print the k most common words and their frequencies for various values of k
for k in [10, 20, 30, 40, 50]:  # Change the values of k as needed
    print(f"Top {k} words in corpus-2:")
    for i, (word, freq) in enumerate(word_freq):
        if i >= k:
            break
        print(f'{word}: {freq}')
    print()
# Out:
# Top 10 words in corpus-2:
# the: 115803
# and: 77418
# to: 64200
# of: 63391
# a: 45610
# I: 36190
# in: 34510
# was: 28604
# he: 27138
# that: 27092
#
# Top 20 words in corpus-2:
# the: 115803
# and: 77418
# to: 64200
# of: 63391
# a: 45610
# I: 36190
# in: 34510
# was: 28604
# he: 27138
# that: 27092
# his: 23385
# with: 21080
# had: 19018
# her: 18334
# not: 17286
# for: 17103
# it: 16924
# you: 16841
# as: 16024
# she: 14742
#
# Top 30 words in corpus-2:
# the: 115803
# and: 77418
# to: 64200
# of: 63391
# a: 45610
# I: 36190
# in: 34510
# was: 28604
# he: 27138
# that: 27092
# his: 23385
# with: 21080
# had: 19018
# her: 18334
# not: 17286
# for: 17103
# it: 16924
# you: 16841
# as: 16024
# she: 14742
# at: 14715
# on: 13383
# is: 13272
# be: 12614
# my: 11262
# have: 10838
# but: 10388
# all: 10067
# him: 8939
# said: 8875
#
# Top 40 words in corpus-2:
# the: 115803
# and: 77418
# to: 64200
# of: 63391
# a: 45610
# I: 36190
# in: 34510
# was: 28604
# he: 27138
# that: 27092
# ...

# %% [markdown]
# ### Distribution code with n-grams=2 corpus-2

# %%
import os
import glob
from collections import Counter
import matplotlib.pyplot as plt
from nltk.util import ngrams
import nltk
nltk.download('punkt')

# Define the path to your corpus folder
corpus_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\Corpus2\\Corpus2'

# Function to read and tokenize a text file into bigrams
def read_and_tokenize_bigrams(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
        words = text.split()
        bigrams = list(ngrams(words, 2))
        return bigrams

# Initialize a Counter to store bigram frequencies
bigram_counter = Counter()

# Iterate through all text files in the corpus folder
for file_path in glob.glob(os.path.join(corpus_folder, '*.txt')):
    bigrams = read_and_tokenize_bigrams(file_path)
    bigram_counter.update(bigrams)

# Sort the bigram frequencies in descending order
bigram_freq = bigram_counter.most_common()

top_bigrams = 30  # Number of top bigrams to print
for i, (bigram, freq) in enumerate(bigram_freq):
    if i >= top_bigrams:
        break
    print(f'{" ".join(bigram)}: {freq}')
# If you want to visualize the distribution, you can use a bar chart
top_bigrams = 30  # Number of top bigrams to visualize
top_bigrams_data = bigram_freq[:top_bigrams]

bigrams, frequencies = zip(*top_bigrams_data)

plt.figure(figsize=(12, 6))
plt.bar([" ".join(bigram) for bigram in bigrams], frequencies)
plt.xlabel('Bigrams')
plt.ylabel('Frequency')
plt.title(f'Top {top_bigrams} Bigrams in the Corpus-2')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vasuk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# of the: 14144
# in the: 9426
# to the: 6627
# and the: 4624
# on the: 4341
# to be: 3855
# at the: 3689
# he had: 3152
# with the: 2986
# in a: 2876
# of his: 2796
# of a: 2741
# he was: 2642
# that he: 2596
# for the: 2580
# with a: 2536
# it was: 2498
# from the: 2445
# had been: 2407
# did not: 2304
# and I: 2264
# was a: 2147
# by the: 2124
# I am: 2010
# in his: 1996
# all the: 1947
# I have: 1869
# out of: 1855
# of her: 1804
# that I: 1714

# %% [markdown]
# #### Different k  - most frequent words n-grams=2 corpus-2

# %%
corpus_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\Corpus2\\Corpus2'

# Function to read and tokenize a text file into bigrams
def read_and_tokenize_bigrams(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
        words = text.split()
        bigrams = list(ngrams(words, 2))
        return bigrams

# Initialize a Counter to store bigram frequencies
bigram_counter = Counter()

# Iterate through all text files in the corpus folder
for file_path in glob.glob(os.path.join(corpus_folder, '*.txt')):
    bigrams = read_and_tokenize_bigrams(file_path)
    bigram_counter.update(bigrams)

# Sort the bigram frequencies in descending order
bigram_freq = bigram_counter.most_common()
# Print the k most common words and their frequencies for various values of k
for k in [10, 20, 30, 40, 50]:  # Change the values of k as needed
    print(f"Top {k} words:")
    for i, (word, freq) in enumerate(bigram_freq):
        if i >= k:
            break
        print(f'{word}: {freq}')
    print()
# Out:
# Top 10 words:
# ('of', 'the'): 14144
# ('in', 'the'): 9426
# ('to', 'the'): 6627
# ('and', 'the'): 4624
# ('on', 'the'): 4341
# ('to', 'be'): 3855
# ('at', 'the'): 3689
# ('he', 'had'): 3152
# ('with', 'the'): 2986
# ('in', 'a'): 2876
#
# Top 20 words:
# ('of', 'the'): 14144
# ('in', 'the'): 9426
# ('to', 'the'): 6627
# ('and', 'the'): 4624
# ('on', 'the'): 4341
# ('to', 'be'): 3855
# ('at', 'the'): 3689
# ('he', 'had'): 3152
# ('with', 'the'): 2986
# ('in', 'a'): 2876
# ('of', 'his'): 2796
# ('of', 'a'): 2741
# ('he', 'was'): 2642
# ('that', 'he'): 2596
# ('for', 'the'): 2580
# ('with', 'a'): 2536
# ('it', 'was'): 2498
# ('from', 'the'): 2445
# ('had', 'been'): 2407
# ('did', 'not'): 2304
#
# Top 30 words:
# ('of', 'the'): 14144
# ('in', 'the'): 9426
# ('to', 'the'): 6627
# ('and', 'the'): 4624
# ('on', 'the'): 4341
# ('to', 'be'): 3855
# ('at', 'the'): 3689
# ('he', 'had'): 3152
# ('with', 'the'): 2986
# ('in', 'a'): 2876
# ('of', 'his'): 2796
# ('of', 'a'): 2741
# ...

# %% [markdown]
# ## Remove stop words corpus-2

# %%
import os
import glob
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords

# Define the path to your corpus folder and the custom output folder
corpus_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\Corpus2\\Corpus2'
custom_output_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\custom_output_folder'  # Create this folder if it doesn't exist

# Get a list of common English stop words
stop_words = set(stopwords.words('english'))

# Function to remove stop words from a given text
def remove_stop_words(text):
    words = nltk.word_tokenize(text)
    words = [word.lower() for word in words if word.lower() not in stop_words]
    return ' '.join(words)

# Process and save each text file in the corpus folder with custom output paths
for file_path in glob.glob(os.path.join(corpus_folder, '*.txt')):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    
    # Remove stop words from the text
    processed_text = remove_stop_words(text)
    
    # Define a custom output file path based on your preferences
    # Here, we use the original filename and place it in the custom output folder
    output_file = os.path.join(custom_output_folder, os.path.basename(file_path))
    
    # Save the processed text to the custom output file
    with open(output_file, 'w', encoding='utf-8') as output_file:
        output_file.write(processed_text)

print("Stop words removed from all files in the corpus folder and saved with custom output file paths.")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vasuk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vasuk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Stop words removed from all files in the corpus folder and saved with custom output file paths.

# %%
# After remvoing stop words saved the files in the output folder 
# Now doing analysis on these words

# %% [markdown]
# #### top 30 words after removing stop words - corpus 2

# %%
# Define the path to your corpus folder
corpus_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\custom_output_folder'

# Function to read and tokenize a text file
def read_and_tokenize(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
        words = text.split()
        return words

# Initialize a Counter to store word frequencies
word_counter = Counter()

# Iterate through all text files in the corpus folder
for file_path in glob.glob(os.path.join(corpus_folder, '*.txt')):
    words = read_and_tokenize(file_path)
    word_counter.update(words)

# Sort the word frequencies in descending order
word_freq = word_counter.most_common()

top_words = 30  # Number of top words to print
for i, (word, freq) in enumerate(word_freq):
    if i >= top_words:
        break
    print(f'{word}: {freq}')
# If you want to visualize the distribution, you can use a bar chart
top_words = 30  # Number of top words to visualize
top_words_data = word_freq[:top_words]

words, frequencies = zip(*top_words_data)

plt.figure(figsize=(12, 6))
plt.bar(words, frequencies)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title(f'Top {top_words} Words in the Corpus-2 after removing stop words')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# code for wordcloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Create a dictionary from the words and frequencies
word_freq_dict = {word: freq for word, freq in zip(words, frequencies)}

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq_dict)

# Display the word cloud using Matplotlib
plt.figure(figsize=(7, 3))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ,: 195603
# .: 97995
# ’: 31084
# “: 28811
# ”: 27944
# ;: 18799
# !: 14611
# ?: 13237
# said: 11859
# '': 7760
# would: 7497
# one: 7392
# ``: 6742
# could: 5846
# :: 5599
# --: 4980
# see: 4312
# like: 4148
# know: 4118
# man: 3998
# time: 3867
# little: 3786
# come: 3727
# must: 3504
# well: 3451
# go: 3396
# mr.: 3369
# never: 3131
# went: 3125
# came: 2875

# %% [markdown]
# #### different frequency k words

# %%
# Define the path to your corpus folder
corpus_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\custom_output_folder'

# Function to read and tokenize a text file
def read_and_tokenize(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
        words = text.split()
        return words

# Initialize a Counter to store word frequencies
word_counter = Counter()

# Iterate through all text files in the corpus folder
for file_path in glob.glob(os.path.join(corpus_folder, '*.txt')):
    words = read_and_tokenize(file_path)
    word_counter.update(words)

# Sort the word frequencies in descending order
word_freq = word_counter.most_common()

# Print the k most common words and their frequencies for various values of k
for k in [10, 20, 30, 40, 50]:  # Change the values of k as needed
    print(f"Top {k} words in corpus-2 after removing stop words:")
    for i, (word, freq) in enumerate(word_freq):
        if i >= k:
            break
        print(f'{word}: {freq}')
    print()
# Out:
# Top 10 words in corpus-2 after removing stop words:
# ,: 195603
# .: 97995
# ’: 31084
# “: 28811
# ”: 27944
# ;: 18799
# !: 14611
# ?: 13237
# said: 11859
# '': 7760
#
# Top 20 words in corpus-2 after removing stop words:
# ,: 195603
# .: 97995
# ’: 31084
# “: 28811
# ”: 27944
# ;: 18799
# !: 14611
# ?: 13237
# said: 11859
# '': 7760
# would: 7497
# one: 7392
# ``: 6742
# could: 5846
# :: 5599
# --: 4980
# see: 4312
# like: 4148
# know: 4118
# man: 3998
#
# Top 30 words in corpus-2 after removing stop words:
# ,: 195603
# .: 97995
# ’: 31084
# “: 28811
# ”: 27944
# ;: 18799
# !: 14611
# ?: 13237
# said: 11859
# '': 7760
# would: 7497
# one: 7392
# ``: 6742
# could: 5846
# :: 5599
# --: 4980
# see: 4312
# like: 4148
# know: 4118
# man: 3998
# time: 3867
# little: 3786
# come: 3727
# must: 3504
# well: 3451
# go: 3396
# mr.: 3369
# never: 3131
# went: 3125
# came: 2875
#
# Top 40 words in corpus-2 after removing stop words:
# ,: 195603
# .: 97995
# ’: 31084
# “: 28811
# ”: 27944
# ...

# %% [markdown]
# #### Distribution code with n-grams=2 corpus-2 after removing stop words

# %%
# Define the path to your corpus folder
corpus_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\custom_output_folder'

# Function to read and tokenize a text file into bigrams
def read_and_tokenize_bigrams(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
        words = text.split()
        bigrams = list(ngrams(words, 2))
        return bigrams

# Initialize a Counter to store bigram frequencies
bigram_counter = Counter()

# Iterate through all text files in the corpus folder
for file_path in glob.glob(os.path.join(corpus_folder, '*.txt')):
    bigrams = read_and_tokenize_bigrams(file_path)
    bigram_counter.update(bigrams)

# Sort the bigram frequencies in descending order
bigram_freq = bigram_counter.most_common()

top_bigrams = 30  # Number of top bigrams to print
for i, (bigram, freq) in enumerate(bigram_freq):
    if i >= top_bigrams:
        break
    print(f'{" ".join(bigram)}: {freq}')
# If you want to visualize the distribution, you can use a bar chart
top_bigrams = 30  # Number of top bigrams to visualize
top_bigrams_data = bigram_freq[:top_bigrams]

bigrams, frequencies = zip(*top_bigrams_data)

plt.figure(figsize=(12, 6))
plt.bar([" ".join(bigram) for bigram in bigrams], frequencies)
plt.xlabel('Bigrams')
plt.ylabel('Frequency')
plt.title(f'Top {top_bigrams} Bigrams in the Corpus-2 after removing stop words')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# . “: 12722
# ” “: 8958
# , ”: 7844
# ” said: 6181
# ? ”: 5179
# , ’: 4366
# ! ”: 4020
# , ,: 3537
# said ,: 3019
# . '': 2990
# “ ’: 2833
# , “: 2622
# . ’: 2572
# . ``: 2411
# '' ``: 1941
# . ,: 1855
# , '': 1817
# well ,: 1808
# , ``: 1753
# “ ,: 1680
# , would: 1658
# , though: 1374
# , could: 1275
# oh ,: 1215
# ’ ,: 1184
# yes ,: 1168
# * *: 1138
# ? '': 1132
# , one: 1113
# , said: 1106

# %% [markdown]
# #### Different frequent k words of bigram =2  after removing stop words

# %%
corpus_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\custom_output_folder'

# Function to read and tokenize a text file into bigrams
def read_and_tokenize_bigrams(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
        words = text.split()
        bigrams = list(ngrams(words, 2))
        return bigrams

# Initialize a Counter to store bigram frequencies
bigram_counter = Counter()

# Iterate through all text files in the corpus folder
for file_path in glob.glob(os.path.join(corpus_folder, '*.txt')):
    bigrams = read_and_tokenize_bigrams(file_path)
    bigram_counter.update(bigrams)

# Sort the bigram frequencies in descending order
bigram_freq = bigram_counter.most_common()
# Print the k most common words and their frequencies for various values of k
for k in [10, 20, 30, 40, 50]:  # Change the values of k as needed
    print(f"Top {k} words:")
    for i, (word, freq) in enumerate(bigram_freq):
        if i >= k:
            break
        print(f'{word}: {freq}')
    print()
# Out:
# Top 10 words:
# ('.', '“'): 12722
# ('”', '“'): 8958
# (',', '”'): 7844
# ('”', 'said'): 6181
# ('?', '”'): 5179
# (',', '’'): 4366
# ('!', '”'): 4020
# (',', ','): 3537
# ('said', ','): 3019
# ('.', "''"): 2990
#
# Top 20 words:
# ('.', '“'): 12722
# ('”', '“'): 8958
# (',', '”'): 7844
# ('”', 'said'): 6181
# ('?', '”'): 5179
# (',', '’'): 4366
# ('!', '”'): 4020
# (',', ','): 3537
# ('said', ','): 3019
# ('.', "''"): 2990
# ('“', '’'): 2833
# (',', '“'): 2622
# ('.', '’'): 2572
# ('.', '``'): 2411
# ("''", '``'): 1941
# ('.', ','): 1855
# (',', "''"): 1817
# ('well', ','): 1808
# (',', '``'): 1753
# ('“', ','): 1680
#
# Top 30 words:
# ('.', '“'): 12722
# ('”', '“'): 8958
# (',', '”'): 7844
# ('”', 'said'): 6181
# ('?', '”'): 5179
# (',', '’'): 4366
# ('!', '”'): 4020
# (',', ','): 3537
# ('said', ','): 3019
# ('.', "''"): 2990
# ('“', '’'): 2833
# (',', '“'): 2622
# ('.', '’'): 2572
# ('.', '``'): 2411
# ("''", '``'): 1941
# ('.', ','): 1855
# (',', "''"): 1817
# ...

# %% [markdown]
# # pre processing the text data

# %%
import os
import glob
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')

# Define the path to your corpus folder and the output folder
corpus_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\Corpus2\\Corpus2'
output_folder = 'C:\\Users\\vasuk\\OneDrive\\Desktop\\sql\\processed_corpus2'

# Ensure the output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Initialize a Porter Stemmer
stemmer = PorterStemmer()

# Define a function to preprocess text
def preprocess_text(text):
    # Tokenize the text
    tokens = nltk.word_tokenize(text)
    
    # Lowercase the tokens
    tokens = [token.lower() for token in tokens]
    
    # Remove punctuation
    tokens = [token for token in tokens if token not in string.punctuation]
    
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
    # Stem the tokens
    tokens = [stemmer.stem(token) for token in tokens]
    
    # Join the tokens back into a cleaned text
    cleaned_text = ' '.join(tokens)
    
    return cleaned_text

# Process and save each text file in the corpus folder
for file_path in glob.glob(os.path.join(corpus_folder, '*.txt')):
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    
    # Preprocess the text
    preprocessed_text = preprocess_text(text)
    
    # Define the output file path
    output_file = os.path.join(output_folder, os.path.basename(file_path))
    
    # Save the preprocessed text to the output file
    with open(output_file, 'w', encoding='utf-8') as output_file:
        output_file.write(preprocessed_text)

print("Text data has been preprocessed and saved in the output folder.")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vasuk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vasuk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Text data has been preprocessed and saved in the output folder.
